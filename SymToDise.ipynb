# %% [markdown]
# Symptom to Disease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./Kaggle/Symptom to Disease.xlsx")

# %%
df.head()
# Out:
#         Disease                       Symptoms
# 0         Cough  Sore throat, chest congestion
# 1      Diabetes    Frequent urination, fatigue
# 2  Hypertension    High blood pressure, stress
# 3      Migraine        Severe headache, nausea
# 4     Arthritis           Joint pain, swelling

# %%
print(df.columns)
# Out:
# Index(['Disease', 'Symptoms'], dtype='object')

# %%
df["Symptoms"] = (
    df["Symptoms"]
    .str.lower()
    .str.strip()
)
